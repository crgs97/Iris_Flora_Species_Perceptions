# %%
# importing all the libraries 
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading the Dataset from system

# %%
data = pd.read_excel(r"D:\Personal files\Data science Materials\ICT Academy_Materials\Data sets\iris.xls")

# %% [markdown]
# # Checking whether the Datasets have been Imported

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Printing out all the Column Headings of the Datasets

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Basic Informations of the Datasets

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SL              150 non-null    float64
#  1   SW              150 non-null    float64
#  2   PL              150 non-null    float64
#  3   PW              150 non-null    float64
#  4   Classification  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Statistical Informations of the Datasets

# %%
data.describe()
# Out:
#                SL          SW          PL          PW
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# # Displaying the respective "Mean" of the Columns from the Dataset

# %%
data.SL.mean()
# Out:
# 5.843333333333335

# %%
data.SW.mean()
# Out:
# 3.0540000000000007

# %%
data.PL.mean()
# Out:
# 3.7586666666666693

# %%
data.PW.mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# # Displaying all the columns mean at once.

# %%
data.mean()
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_5416\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Checking for any 'Null Value' present in the Dataset.

# %%
data.SL.isna().value_counts()
# Out:
# False    150
# Name: SL, dtype: int64

# %%
data.SW.isna().value_counts()
# Out:
# False    150
# Name: SW, dtype: int64

# %%
data.PL.isna().value_counts()
# Out:
# False    150
# Name: PL, dtype: int64

# %%
data.PW.isna().value_counts()
# Out:
# False    150
# Name: PW, dtype: int64

# %%
#finding out 
data.isna().value_counts()
# Out:
# SL     SW     PL     PW     Classification
# False  False  False  False  False             150
# dtype: int64

# %% [markdown]
# # Plotting different Parameters V/s Species_Classifications respectively;

# %%
plt.figure(figsize=(12,12))
plt.title('Flora Iris V/S Petal Length', fontsize=28)
a=sns.boxenplot(x=data.Classification, y=data.PL)
a.set_xlabel('Classifications')
a.set_ylabel('Petal Length')
# Out:
# Text(0, 0.5, 'Petal Length')

# %%
plt.figure(figsize=(20,5))
plt.title('Sepal Width V/s Flora Iris', fontsize=28)
plt.scatter(x= data.SW, y=data.Classification)
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.set_palette("Paired")
plt.title('Parametres V/s Flora Iris', fontsize=26)
c=sns.scatterplot(x= data.SL, y=data.Classification)
c=sns.scatterplot(x= data.SW, y=data.Classification)
c=sns.scatterplot(x= data.PW, y=data.Classification)
c=sns.scatterplot(x= data.PL, y=data.Classification)
plt.legend(data)
c.set_xlabel('Parametres')
c.set_ylabel('Classification')
plt.show()

# %%
plt.figure(figsize=(15,5))
plt.title('Flora Iris V/S Petal Width', fontsize=25)
d=sns.barplot(x=data.Classification, y=data.PW)
d.set_xlabel('Classifications')
d.set_ylabel('Petal Width');

# %%
plt.figure(figsize=(20,5))
plt.title('Sepal Length V/S Flora Iris', fontsize=26)
e=sns.barplot(y=data.Classification, x=data.SL, orient ='h')
e.set_xlabel('Sepal Length');
